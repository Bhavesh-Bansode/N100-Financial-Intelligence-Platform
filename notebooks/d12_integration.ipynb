# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../data/nifty100.db")

schema = pd.read_sql(
    "PRAGMA table_info(financial_ratios)",
    conn
)

schema
# Out:
#     cid                         name     type  notnull dflt_value  pk
# 0     0                           id  INTEGER        0       None   1
# 1     1                   company_id     TEXT        1       None   0
# 2     2                         year  INTEGER        1       None   0
# 3     3        net_profit_margin_pct     REAL        0       None   0
# 4     4  operating_profit_margin_pct     REAL        0       None   0
# 5     5         return_on_equity_pct     REAL        0       None   0
# 6     6               debt_to_equity     REAL        0       None   0
# 7     7            interest_coverage     REAL        0       None   0
# 8     8               asset_turnover     REAL        0       None   0
# 9     9            free_cash_flow_cr     REAL        0       None   0
# 10   10                     capex_cr     REAL        0       None   0
# 11   11           earnings_per_share     REAL        0       None   0
# 12   12         book_value_per_share     REAL        0       None   0
# 13   13    dividend_payout_ratio_pct     REAL        0       None   0
# 14   14                total_debt_cr     REAL        0       None   0
# 15   15      cash_from_operations_cr     REAL        0       None   0
# 16   16             revenue_cagr_5yr     REAL        0       None   0
# 17   17                 pat_cagr_5yr     REAL        0       None   0
# 18   18                 eps_cagr_5yr     REAL        0       None   0
# 19   19      composite_quality_score     REAL        0       None   0

# %%
tables = pd.read_sql(
    "SELECT name FROM sqlite_master WHERE type='table'",
    conn
)

print(tables)
# Out:
#                 name
# 0          companies
# 1      profitandloss
# 2       balancesheet
# 3           cashflow
# 4           analysis
# 5          documents
# 6        prosandcons
# 7            sectors
# 8       stock_prices
# 9         market_cap
# 10  financial_ratios
# 11       peer_groups

# %%
pd.read_sql(
    "SELECT COUNT(*) AS rows FROM companies",
    conn
)
# Out:
#    rows
# 0    92

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../data/nifty100.db")

# %%
companies = pd.read_sql(
    "SELECT * FROM companies",
    conn
)

profitandloss = pd.read_sql(
    "SELECT * FROM profitandloss",
    conn
)

balancesheet = pd.read_sql(
    "SELECT * FROM balancesheet",
    conn
)

cashflow = pd.read_sql(
    "SELECT * FROM cashflow",
    conn
)

financial_ratios = pd.read_sql(
    "SELECT * FROM financial_ratios",
    conn
)

# %%
print(companies.shape)
print(profitandloss.shape)
print(balancesheet.shape)
print(cashflow.shape)
print(financial_ratios.shape)
# Out:
# (92, 12)
# (1164, 15)
# (1140, 13)
# (1056, 7)
# (1041, 20)

# %%
financial_ratios.columns
# Out:
# Index(['id', 'company_id', 'year', 'net_profit_margin_pct',
#        'operating_profit_margin_pct', 'return_on_equity_pct', 'debt_to_equity',
#        'interest_coverage', 'asset_turnover', 'free_cash_flow_cr', 'capex_cr',
#        'earnings_per_share', 'book_value_per_share',
#        'dividend_payout_ratio_pct', 'total_debt_cr', 'cash_from_operations_cr',
#        'revenue_cagr_5yr', 'pat_cagr_5yr', 'eps_cagr_5yr',
#        'composite_quality_score'],
#       dtype='str')

# %%
pd.read_sql("""
SELECT *
FROM financial_ratios
LIMIT 5
""", conn)
# Out:
#    id company_id      year  net_profit_margin_pct  \
# 0   1        ABB  Dec 2012                   8.77
# 1   3        ABB  Mar 2014                   8.70
# 2   5        ABB  Mar 2015                  10.00
# 3   7        ABB  Mar 2016                   9.76
# 4   9        ABB  Mar 2017                   9.54
#
#    operating_profit_margin_pct  return_on_equity_pct  debt_to_equity  \
# 0                         12.0                 22.41             0.0
# 1                         12.0                 25.13             0.0
# 2                         14.0                 24.44             0.0
# 3                         14.0                 21.34             0.0
# 4                         14.0                 19.97             0.0
#
#    interest_coverage  asset_turnover  free_cash_flow_cr  capex_cr  \
# 0                NaN          1.8225               42.0      59.0
# 1                NaN          1.9982                0.0       0.0
# 2                NaN          1.6659            -1899.0    1864.0
# 3           138.3333          1.6176              728.0     816.0
# 4           227.5000          1.4051              459.0    1730.0
#
#    earnings_per_share  book_value_per_share  dividend_payout_ratio_pct  \
# 0                68.0                3.0810                       25.0
# 1                93.0                3.7524                       25.0
# 2               108.0                4.4619                       29.0
# 3               120.0                5.6905                       29.0
# 4               130.0                6.6048                       31.0
#
#    total_debt_cr  cash_from_operations_cr revenue_cagr_5yr pat_cagr_5yr  \
# 0            0.0                    101.0             None         None
# 1            0.0                      0.0             None         None
# 2            0.0                    -35.0             None         None
# 3            0.0                   1544.0             None         None
# 4            0.0                   2189.0             None         None
#
#   eps_cagr_5yr composite_quality_score
# 0         None                    None
# 1         None                    None
# 2         None                    None
# 3         None                    None
# 4         None                    None

# %%
import pandas as pd

pd.read_sql(
    "SELECT COUNT(*) AS rows FROM financial_ratios",
    conn,
)
# Out:
#    rows
# 0  1041

# %%
pd.read_sql(
    """
    SELECT COUNT(*)
    FROM financial_ratios
    WHERE year LIKE '%TTM%';
    """,
    conn,
)
# Out:
#    COUNT(*)
# 0         0
