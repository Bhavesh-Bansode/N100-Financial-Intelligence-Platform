# %%
ratios = pd.read_sql("SELECT * FROM financial_ratios", conn)

print(ratios.columns.tolist())

conn.close()
# Out:
# ['id', 'company_id', 'year', 'net_profit_margin_pct', 'operating_profit_margin_pct', 'return_on_equity_pct', 'debt_to_equity', 'interest_coverage', 'asset_turnover', 'free_cash_flow_cr', 'capex_cr', 'earnings_per_share', 'book_value_per_share', 'dividend_payout_ratio_pct', 'total_debt_cr', 'cash_from_operations_cr', 'revenue_cagr_5yr', 'pat_cagr_5yr', 'eps_cagr_5yr', 'composite_quality_score']

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../data/nifty100.db")
companies = pd.read_sql("SELECT * FROM companies", conn)

print(companies.columns.tolist())

print()

print(
    ratios[
        ["company_id", "year", "free_cash_flow_cr"]
    ].head(20)
)
# Out:
# ['id', 'company_logo', 'company_name', 'chart_link', 'about_company', 'website', 'nse_profile', 'bse_profile', 'face_value', 'book_value', 'roce_percentage', 'roe_percentage']
#
#     company_id     year  free_cash_flow_cr
# 0          ABB  2012-12               42.0
# 1          ABB  2014-03                0.0
# 2          ABB  2015-03            -1899.0
# 3          ABB  2016-03              728.0
# 4          ABB  2017-03              459.0
# 5          ABB  2018-03             -994.0
# 6          ABB  2019-03             -459.0
# 7          ABB  2020-03             -206.0
# 8          ABB  2021-03             -225.0
# 9          ABB  2022-03              161.0
# 10         ABB  2023-03             -922.0
# 11         ABB  2024-03             1095.0
# 12         ABB      TTM                NaN
# 13  ADANIENSOL  2014-03                0.0
# 14  ADANIENSOL  2015-03            -1899.0
# 15  ADANIENSOL  2016-03              728.0
# 16  ADANIENSOL  2017-03              459.0
# 17  ADANIENSOL  2018-03             -994.0
# 18  ADANIENSOL  2019-03             -459.0
# 19  ADANIENSOL  2020-03             -206.0

# %%
profit = pd.read_sql("SELECT * FROM profitandloss", conn)

print(profit.columns.tolist())
# Out:
# ['id', 'company_id', 'year', 'sales', 'expenses', 'operating_profit', 'opm_percentage', 'other_income', 'interest', 'depreciation', 'profit_before_tax', 'tax_percentage', 'net_profit', 'eps', 'dividend_payout']
